# %% [markdown]
# #**Understanding Student Well-being : A Holistic Approach (Local-study)** 🧑🏻‍🎓
#
#
# ![Flag_of_Tunisia_(1959–1999).svg.png](data:image/png;base64,...)

# %% [markdown]
# ##**IEEE ESPRIT SB TEAM**
#  ![esprit.png](data:image/png;base64,...)
#
#
#
#
#
#
# *   Mahmoud Aziz Ammar
# *   Salma Turki
# *   Bilel Kort

# %% [markdown]
# In this lab, we will prepare and clean the dataset, which is essential for any data-driven project. Our goal is to identify actionable strategies to leverage this analysis within educational platforms, ultimately aiming to enhance the overall learning experiences of students In Tunisia.
#
# This lab is divided into 4 key steps (CRISP-DM steps):
#
#
#
# *   **Business Understanding**
# *   **Data understanding & Data Exploration**
# *   **Data Preparation (cleaning)**
# *   **Data Analysis & modeling**

# %% [markdown]
# # **Step 1 : Business Understanding 👓**

# %% [markdown]
# ###**Problem Statement**
# The project entails the examination of various dimensions of tunisian students' lives, including social relationships, physical and mental health, and emotional resilience. The primary goal is to conduct an in-depth analysis of this data, extracting novel insights into the interplay between these aspects of students' lives in Tunisia .

# %% [markdown]
# ### **Stakeholders**
# ####***Tunisian Students 👨🧑‍🎓:***
#
# The primary stakeholders in this challenge are students
# themselves. Understanding how their social relationships, physical and mental health, and emotional resilience affect their academic success and overall development is crucial for their well-being and future success.
#
#
# ---
#
#
# ####***Parents and families 👪:***
#
# Parents and families play a critical role in
# their children's lives and want to support their academic and personal
# development. Understanding the intricate interactions within students' lives can help parents and families be more effective advocates and provide better support at home.

# %% [markdown]
# ###**Descriptive Statistics:**
#
# 1-What is your gender?
#
# 2-What field of study are you pursuing?
#
# 3-How many close friends do you have? (Please enter the number)
#
# 4-How would you rate the strength of your social connections?
#
# 5-Are you involved in any extracurricular activities?
#
# 6-How would you rate your overall physical health?
#
# 7-How many hours of physical activity do you engage in per week?
#
# 8-Do you have any chronic health conditions?
#
# 9-On a scale of 1 to 10, how would you rate your current mental well-being?
#
# 10-Have you ever sought mental health support or counseling?
#
# 11-How do you cope with stress?
#
# 12-What factors most significantly affect your academic performance?
#
# 13-Are you satisfied with your academic performance?

# %% [markdown]
# # **Step 2: Data Understanding and  Exploration 🗂️ 📊**

# %% [markdown]
# **-This dataset contains around 13 features that create the most impact on the Tunisian Student.**
#
#
#
#
#
#
# **Psychological Factors:👨‍⚕️**
#
# 1. Mental Well-being
# 2. Mental Health Support
# 3. Coping with Stress
#
# **Physiological Factors:👨‍⚕️**
# 4. Physical Health Rating
# 5. Physical Activity
# 6. Chronic Health Conditions
#
#
#
# **Academic Factors :🎓**
# 7. Field of Study
# 8. Academic Performance Influencers
# 9. Satisfaction with Academic Performance
#
# **Social Factors 👨‍👦‍👦:**
# 10. Gender
# 11. Close Friends
# 12. Strength of Social Connections
# 13. Extracurricular Activities

# %% [markdown]
# * Import libraries

# %%
#data manipulation and analysis
import numpy as np
import pandas as pd
#creating various types of plots and visualizations
import matplotlib.pyplot as plt
import seaborn as sns
#Normalization
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# Initial Data Exploration
# Here are the steps we've taken during the Data Understanding phase:
#
# * Loading the Dataset: We loaded the dataset from the "StressLevelDataset.csv"
# file to examine its contents.

# %%
data = pd.read_excel("Local dataset (survey).xlsx")

# %%
# Displaying the first few rows of the 'data' DataFrame to inspect its initial data entries
pd.set_option('display.max_columns', None)
data.head(5)
# Out:
#                 Timestamp 1-Gender :     2-Study field  \
# 0 2023-11-26 23:23:37.843       male       Engineering
# 1 2023-11-26 23:28:58.085     female       Engineering
# 2 2023-11-26 23:47:17.525       male  Computer Science
# 3 2023-11-27 00:04:11.915       male  Computer Science
# 4 2023-11-27 00:13:49.141     female  Computer Science
#
#    3-How many close friends do you have ?  (Enter the number)  \
# 0                                                2.0
# 1                                                3.0
# 2                                                7.0
# 3                                                3.0
# 4                                                2.0
#
#    4-How would you rate the strength of your social connections ?   \
# 0                                                3.0
# 1                                                3.0
# 2                                                4.0
# 3                                                4.0
# ...

# %% [markdown]
# * Data Structure: We determined the size of the dataset (number of rows and columns) to understand its overall dimensions.

# %%
data.shape
# Out:
# (116, 14)

# %% [markdown]
# => **The dataset contains a total of 116 records and 14 features.**

# %%
#the list of column names in the DataFrame 'data'
data.columns
# Out:
# Index(['Timestamp', '1-Gender :', '2-Study field',
#        '3-How many close friends do you have ?  (Enter the number)',
#        '4-How would you rate the strength of your social connections ? ',
#        '5- Are you involved in any extracurricular activities? ',
#        '6-How would you rate your overall physical health?',
#        '7-How many hours of physical activity do you engage in per week? ',
#        '8-Do you have any chronic health conditions? ',
#        '9-On a scale of 1 to 10, how would you rate your current mental well-being?',
#        '10-Have you ever sought mental health support or counseling?',
#        '11- How do you cope with stress? ',
#        '12-  What affects more your academic performance ?   ',
#        '13- Are you satisfied with your academic performance?'],
#       dtype='object')

# %%
# Output a summary of information about the DataFrame 'data,' including data types, non-null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 14 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Timestamp                                                                    116 non-null    datetime64[ns]
#  1   1-Gender :                                                                   116 non-null    object
#  2   2-Study field                                                                116 non-null    object
#  3   3-How many close friends do you have ?  (Enter the number)                   114 non-null    float64
#  4   4-How would you rate the strength of your social connections ?               115 non-null    float64
#  5   5- Are you involved in any extracurricular activities?                       116 non-null    object
# ...

# %% [markdown]
# => these Summary statistics provide a basic understanding of the distribution of numerical & categorical features.
#
#
# **we had 10 object features & 1 numerical feature & 1 datatime & 2 floats  .**

# %% [markdown]
# # **Step 3: Data Preparation (cleaning)**

# %% [markdown]
# ### 1-**Dimensionality Reduction**

# %%
# Supprimer la colonne "Timestamp" du DataFrame "data"
data.drop(columns=['Timestamp'], inplace=True)

# %% [markdown]
# **=> Removed the "Timestamp" column as it captured form submission times, which are irrelevant to our analysis.**

# %%
# Define a list for the new column names
new_column_names = [
    'Gender',
    'Field of Study',
    'Close Friends',
    'Strength of Social Connections',
    'Extracurricular Activities',
    'Physical Health Rating',
    'Physical Activity',
    'Chronic Health Conditions',
    'Mental Well-being',
    'Mental Health Support',
    'Coping with Stress',
    'Academic Performance Influencers',
    'Satisfaction with Academic Performance'
]

# Rename the columns based on the new names
data.columns = new_column_names

# %% [markdown]
# **=>Rename the DataFrame columns to make them more meaningful.**

# %%
data.head()
# Out:
#    Gender    Field of Study  Close Friends  Strength of Social Connections  \
# 0    male       Engineering            2.0                             3.0
# 1  female       Engineering            3.0                             3.0
# 2    male  Computer Science            7.0                             4.0
# 3    male  Computer Science            3.0                             4.0
# 4  female  Computer Science            2.0                             4.0
#
#   Extracurricular Activities Physical Health Rating  Physical Activity  \
# 0                        Yes              Very Good  4 hours - 6 hours
# 1                        Yes                   Fair  less than 2 hours
# 2                        Yes                   Fair  less than 2 hours
# 3                         No                   Fair  less than 2 hours
# 4                        Yes                   Fair   2 hours - 4hours
#
#   Chronic Health Conditions  Mental Well-being Mental Health Support  \
# ...

# %% [markdown]
# ### 2- **Detect Outliers**

# %%
#we use the boxplot to detect any outliers
plt.figure(figsize=(12, 8))
sns.boxplot(data)
plt.title('Boxplot for Each Attribute')
plt.xticks(fontsize=8, rotation=45, ha="right")
plt.show()

# %% [markdown]
# => We identified outliers within the dataset, specifically in the **Strength of Social Connections , close freinds and mental well-being'** feature  has 10 and 68 as extreme values

# %%
# Identify outliers in 'Close Friends' column
outliers_mask = data['Close Friends'] > 5

# Replace outliers with the mean
data.loc[outliers_mask, 'Close Friends'] = 3

# %% [markdown]
# **=> replaces outliers with the mean, but this replacement is done only in the 'Close Friends' column. The other columns, such as 'Strength of Social Connections' and 'Mental Well-being', are left untouched even if they contain outliers because those values are a part of data**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Gender                                  116 non-null    object
#  1   Field of Study                          116 non-null    object
#  2   Close Friends                           114 non-null    float64
#  3   Strength of Social Connections          115 non-null    float64
#  4   Extracurricular Activities              116 non-null    object
#  5   Physical Health Rating                  116 non-null    object
#  6   Physical Activity                       115 non-null    object
#  7   Chronic Health Conditions               116 non-null    object
#  8   Mental Well-being                       116 non-null    int64
#  9   Mental Health Support                   116 non-null    object
# ...

# %% [markdown]
# ### 3-**Duplicate Records**

# %%
data.duplicated().sum()
# Out:
# 1

# %% [markdown]
# => on a 2 duplicated records

# %%
data = data.drop_duplicates()

# %% [markdown]
# => we removed duplicate rows from  DataFrame

# %% [markdown]
# ### 4-**missing values**

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(data=data.isnull(),cbar=True, cmap="GnBu")
plt.title('Missing values heatmap')
plt.show()

# %% [markdown]
# **=> This visualization can serve as a confirmation that Our dataset contain some  missing values in close friends and strength of social connections and physical activities .**

# %%
# Supprimer les lignes contenant des valeurs manquantes
data = data.dropna()

# %% [markdown]
# ###**5-Data visualtions**

# %%
# Calculer les pourcentages
satisfaction_percentage = data['Satisfaction with Academic Performance'].value_counts(normalize=True) * 100

# Créer un diagramme en barres
plt.figure(figsize=(6, 4))
sns.barplot(x=satisfaction_percentage.index, y=satisfaction_percentage.values)
plt.title('Distribution de Satisfaction with Academic Performance (en pourcentage)')
plt.xlabel('Satisfaction with Academic Performance')
plt.ylabel('Pourcentage')
plt.show()

# %% [markdown]
# **=>According to the graph, approximately 1/3 of Tunisian students are not satisfied with their academic performance.**

# %% [markdown]
# ##A-**Academic Factors**

# %%
# Liste des colonnes à visualiser
columns_to_visualize = [

  'Field of Study',
    'Academic Performance Influencers',
]

# Créer des sous-plots pour chaque colonne
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
fig.subplots_adjust(hspace=0.5)

for i, column in enumerate(columns_to_visualize):
    row = i // 4
    col = i % 4

    # Choix du type de diagramme en fonction du type de données
    if data[column].dtype == 'object':
        sns.countplot(x=column, data=data, ax=axes[row, col])
    else:
        sns.histplot(x=column, data=data, ax=axes[row, col], bins=20)

    axes[row, col].set_title(f'Distribution of {column}')
    axes[row, col].tick_params(axis='x', labelsize=10)  # Ajuster la taille des étiquettes de l'axe x
    axes[row, col].tick_params(axis='x', rotation=90)  # Rotation des étiquettes de l'axe x

# Supprimer les sous-plots non utilisés
for i in range(len(columns_to_visualize), 3 * 4):
    fig.delaxes(axes.flatten()[i])

# Afficher les sous-plots
plt.show()

# %% [markdown]
# **1-Field of Study:**
#
# The survey indicates a predominant number of respondents studying engineering, reflecting a concentration in this academic field.
#
#
# **2-Academic Performance Influencers:**
#
# The majority of respondents consider mental state, physical health, and study habits as the primary influencers on academic performance. This understanding emphasizes the importance of a holistic approach to academic success, encompassing both physical and mental well-being, along with effective study practices.

# %% [markdown]
# ##B-**Social Factors**

# %%
# Liste des colonnes à visualiser
columns_to_visualize = [

  'Gender',
    'Close Friends',
    'Strength of Social Connections',
    'Extracurricular Activities',
]

# Créer des sous-plots pour chaque colonne
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
fig.subplots_adjust(hspace=0.5)

for i, column in enumerate(columns_to_visualize):
    row = i // 4
    col = i % 4

    # Choix du type de diagramme en fonction du type de données
    if data[column].dtype == 'object':
        sns.countplot(x=column, data=data, ax=axes[row, col])
    else:
        sns.histplot(x=column, data=data, ax=axes[row, col], bins=20)

    axes[row, col].set_title(f'Distribution of {column}')
    axes[row, col].tick_params(axis='x', labelsize=10)  # Ajuster la taille des étiquettes de l'axe x

# Supprimer les sous-plots non utilisés
for i in range(len(columns_to_visualize), 3 * 4):
    fig.delaxes(axes.flatten()[i])

# Afficher les sous-plots
plt.show()

# %% [markdown]
# Based on the Social  Factors
#
# **1-Gender:**
#
# Approximately 60% of the respondents identify as women. This suggests a relatively balanced gender distribution, with a slight majority of women in the surveyed population.
#
# **2-Close Friends:**
#
# The majority of respondents report having around 3 close friends. This indicates a social environment where people may have a moderate number of close connections.
#
# **3-Strength of Social Connections:**
#
# The average strength of social connections falls between 3 and 4. While this indicates a moderate level, more details would be needed to understand the specific dynamics and factors influencing social connections.
#
# **4-Extracurricular Activities:**
#
# Around 60% of respondents are involved in extracurricular activities. This suggests a significant portion of the surveyed population is actively engaged in additional pursuits beyond academic or work-related responsibilities

# %% [markdown]
# ###C-**Physiological Factors :👨‍⚕️**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Liste des colonnes à visualiser
columns_to_visualize = [

   'Physical Health Rating',
    'Physical Activity',
    'Chronic Health Conditions',
]

# Créer des sous-plots pour chaque colonne
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
fig.subplots_adjust(hspace=0.5)

for i, column in enumerate(columns_to_visualize):
    row = i // 4
    col = i % 4

    # Choix du type de diagramme en fonction du type de données
    if data[column].dtype == 'object':
        sns.countplot(x=column, data=data, ax=axes[row, col])
    else:
        sns.histplot(x=column, data=data, ax=axes[row, col], bins=20)

    axes[row, col].set_title(f'Distribution of {column}')
    axes[row, col].tick_params(axis='x', labelsize=8)  # Ajuster la taille des étiquettes de l'axe x
    axes[row, col].tick_params(axis='x', rotation=45)  # Rotation des étiquettes de l'axe x

# Supprimer les sous-plots non utilisés
for i in range(len(columns_to_visualize), 3 * 4):
    fig.delaxes(axes.flatten()[i])

# Afficher les sous-plots
plt.show()

# %% [markdown]
# **1-Physical Health Rating:**
# The results for physical health are positive, suggesting a generally good physical health rating among the respondents in Tunisia.
#
# **2-Physical Activity:**
#
# The majority of respondents engage in physical activity for less than 2 hours per week
#
# **3-Chronic Health Conditions:**
#
# The majority not reporting chronic health conditions is a positive indicator, reflecting overall good health among the surveyed individuals.

# %% [markdown]
# ###D-**Psychological Factors**:👨‍⚕️

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Liste des colonnes à visualiser
columns_to_visualize = [

    'Mental Well-being',
    'Mental Health Support',
    'Coping with Stress',
]

# Créer des sous-plots pour chaque colonne
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
fig.subplots_adjust(hspace=0.5)

for i, column in enumerate(columns_to_visualize):
    row = i // 4
    col = i % 4

    # Choix du type de diagramme en fonction du type de données
    if data[column].dtype == 'object':
        sns.countplot(x=column, data=data, ax=axes[row, col])
    else:
        sns.histplot(x=column, data=data, ax=axes[row, col], bins=20)

    axes[row, col].set_title(f'Distribution of {column}')
    axes[row, col].tick_params(axis='x', labelsize=8)  # Ajuster la taille des étiquettes de l'axe x
    axes[row, col].tick_params(axis='x', rotation=90)  # Rotation des étiquettes de l'axe x


# Supprimer les sous-plots non utilisés
for i in range(len(columns_to_visualize), 3 * 4):
    fig.delaxes(axes.flatten()[i])

# Afficher les sous-plots
plt.show()

# %% [markdown]
# Based on the Psychological Factors
#
# **1-Mental Well-being:**
#
# Respondents, on average, reported a moderate level of mental well-being, with scores ranging from 6 to 7 out of 10.
#
# **2-Mental Health Support:**
#
# A significant 75% feel they lack mental health support, indicating a potential need for increased resources or assistance.
#
# **3-Coping with Stress:**
#
# The majority use diverse strategies, including   task prioritization & positive self-talk and affirmations , highlighting varied approaches to stress management.**

# %% [markdown]
# ##**6-Encoding**

# %%
encoded_data = data.copy()

# Définir le mappage pour chaque colonne
mapping_dict = {
    'Gender': {'male': 1, 'female': 2},
    'Field of Study': {'Engineering': 1, 'Computer Science': 2, 'Medicine': 3, 'Psychology': 4, 'Literature': 5, 'other': 6, 'Political Science': 7, 'Economics': 8},
    'Extracurricular Activities': {'Yes': 1, 'No': 0},
    'Physical Health Rating': {'Poor': 1, 'Fair': 2, 'Good': 3, 'Very Good': 4, 'Excellent': 5},
    'Physical Activity': {'less than 2 hours': 1, '2 hours - 4hours': 2, '4 hours - 6 hours': 3, '+ 6 hours': 4},
    'Chronic Health Conditions': {'no': 0, 'yes': 1},
    'Mental Health Support': {'no': 0, 'yes': 1},
    'Coping with Stress': {'Setting and prioritizing tasks': 1, 'Positive self-talk and affirmations': 2, 'Praying': 3, 'Distancing oneself from others and activities': 4, 'Learning Environment': 5, 'Study Habits': 6, 'Family Support': 7, 'Seeking professional support or counseling': 8, 'Talking with loved ones': 9, 'Sleeping': 10, 'Sport': 11, 'Netflix & Chill': 12},
    'Academic Performance Influencers': {'Physical and mental health': 1, 'Study Habits': 2, 'Learning Environment': 3, 'Attendance at the educational institution': 4, 'Family Support': 5},
    'Satisfaction with Academic Performance': {'No': 0, 'Yes': 1},
}

# Appliquer le mappage pour chaque colonne
for column, mapping in mapping_dict.items():
    encoded_data[column] = encoded_data[column].map(mapping)

# %%
encoded_data.head()
# Out:
#    Gender  Field of Study  Close Friends  Strength of Social Connections  \
# 0       1             1.0            2.0                             3.0
# 1       2             1.0            3.0                             3.0
# 2       1             2.0            3.0                             4.0
# 3       1             2.0            3.0                             4.0
# 4       2             2.0            2.0                             4.0
#
#    Extracurricular Activities  Physical Health Rating  Physical Activity  \
# 0                           1                       4                  3
# 1                           1                       2                  1
# 2                           1                       2                  1
# 3                           0                       2                  1
# 4                           1                       2                  2
#
#    Chronic Health Conditions  Mental Well-being  Mental Health Support  \
# ...

# %% [markdown]
# ##**7-normalisation**

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt


# Normaliser les données avec la standardisation (Z-score)
scaler = StandardScaler()
normalized_data = pd.DataFrame(scaler.fit_transform(encoded_data), columns=encoded_data.columns)

# %%
normalized_data.head()
# Out:
#      Gender  Field of Study  Close Friends  Strength of Social Connections  \
# 0 -1.266748       -0.740225      -0.500595                       -0.504562
# 1  0.789423       -0.740225       0.257062                       -0.504562
# 2 -1.266748       -0.221040       0.257062                        0.625656
# 3 -1.266748       -0.221040       0.257062                        0.625656
# 4  0.789423       -0.221040      -0.500595                        0.625656
#
#    Extracurricular Activities  Physical Health Rating  Physical Activity  \
# 0                    0.774597                1.070657           1.475894
# 1                    0.774597               -0.654718          -0.868789
# 2                    0.774597               -0.654718          -0.868789
# 3                   -1.290994               -0.654718          -0.868789
# 4                    0.774597               -0.654718           0.303553
#
#    Chronic Health Conditions  Mental Well-being  Mental Health Support  \
# ...

# %% [markdown]
# ##**8-correlation Matrix**

# %%
# Calculer la matrice de corrélation
correlation_matrix = normalized_data.corr()

# Créer une heatmap avec Seaborn
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matrice de Corrélation (Données Normalisées)')
plt.show()

# %% [markdown]
# **=> The strength of those relationships is moderate, indicating that while there is a correlation, it is not extremely strong.**
#
# -A correlation of 0.42 between mental well-being and physical health suggests a moderate positive relationship between these two variables. This implies that, on average, an improvement in mental physcial well-being is associated with an improvement in physical health, and vice versa.

# %% [markdown]
# # **Step 4:  Modeling**

# %% [markdown]
# #**K-Means**

# %% [markdown]
# **K-means clustering is an appropriate method for analyzing the relationship between psychological, physiological, social, and academic factors in student stress for 2  reasons**
#
# #**1-Unsupervised Learning**:
# K-means is an unsupervised learning algorithm, In the context of student , we may not have clear-cut categories or labels for the different levels or types of academic experiences.
#
# #**2-Grouping and Pattern Recognition**:
# This can help identify patterns and relationships between the various factors that contribute to student stress. For instance, we might find that students with poor sleep quality tend to have higher levels of anxiety and academic stress.

# %%
print(len(data))  # Assurez-vous que cela correspond au nombre de lignes dans vos données originales
# Out:
# 112

# %%
# Remplacez les valeurs NaN par la moyenne des colonnes
data_cleaned = encoded_data.fillna(encoded_data.mean())

# Vérifiez si des valeurs NaN subsistent
print(data_cleaned.isnull().sum())

# Standardisez les données
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_cleaned)
# Out:
# Gender                                    0
# Field of Study                            0
# Close Friends                             0
# Strength of Social Connections            0
# Extracurricular Activities                0
# Physical Health Rating                    0
# Physical Activity                         0
# Chronic Health Conditions                 0
# Mental Well-being                         0
# Mental Health Support                     0
# Coping with Stress                        0
# Academic Performance Influencers          0
# Satisfaction with Academic Performance    0
# dtype: int64

# %%
# Perform K-Means clustering
kmeans = KMeans(n_clusters=2, init='k-means++', max_iter=300, n_init=10, random_state=42)
kmeans.fit(data_scaled)

# Apply PCA to reduce dimensionality to 2 components
pca = PCA(n_components=2)  # Reduce to 2 components
pca_result = pca.fit_transform(data_scaled)

# Add the cluster labels to the PCA result
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
pca_df['cluster'] = kmeans.labels_

# Plot the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PC1', y='PC2', hue='cluster', palette='viridis', data=pca_df)
plt.title('K-Means Clustering of Academic Factors')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.show()

# %% [markdown]
# **=> In conclusion, the analysis of student well-being data revealed two distinct clusters with notable variations in social relationships, extracurricular engagement, coping mechanisms for stress, and academic influences. Cluster differences in mental well-being and satisfaction with academic performance suggest the presence of nuanced factors affecting students**

# %%
# Assuming 'kmeans' is your fitted KMeans model
kmeans_labels = kmeans.labels_

# Add the cluster labels to the scaled data
data_scaled = pd.DataFrame(data_scaled, columns=data_cleaned.columns)
data_scaled['cluster'] = kmeans_labels

# Calculate cluster means for each attribute
cluster_means = data_scaled[data_scaled['cluster'].isin([0, 1])].groupby('cluster').mean()

# Transpose the DataFrame for plotting
cluster_means = cluster_means.T

# Plot the cluster means as bar plots
cluster_means.plot(kind='bar', figsize=(12, 6), colormap='viridis')
plt.title('Moyennes des Caractéristiques par Cluster')
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Moyenne')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# **=>  Cluster 1, and Cluster 2 represent 2 distinct groups of Tunisian students. Each group is characterized by specific traits and behaviors, as indicated by the average values of the features.**
