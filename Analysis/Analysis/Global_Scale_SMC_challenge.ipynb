# %% [markdown]
# #**Understanding Student Well-being : A Holistic Approach (Global)** 🧑🏻‍🎓 🌐
#
#
# ![66020_globe_world_earth_internet_global_icon.png](data:image/png;base64,...)

# %% [markdown]
# ##**IEEE ESPRIT SB TEAM**
#  ![esprit.png](data:image/png;base64,...)
#
#
#
#
#
#
# *   Mahmoud Aziz Ammar
# *   Salma Turki
# *   Bilel Kort

# %% [markdown]
# In this lab, we will prepare and clean the dataset, which is essential for any data-driven project. Our goal is to identify actionable strategies to leverage this analysis within educational platforms, ultimately aiming to enhance the overall learning experiences of students.
#
# This lab is divided into 4 key steps (CRISP-DM steps):
#
#
#
# *   **Business Understanding**
# *   **Data understanding & Data Exploration**
# *   **Data Preparation (cleaning)**
# *   **Data Analysis & modeling**

# %% [markdown]
# # **Step 1 : Business Understanding**

# %% [markdown]
# ###**Problem Statement**
# The project entails the examination of various dimensions of students' lives, including social relationships, physical and mental health, and emotional resilience. The primary goal is to conduct an in-depth analysis of this data, extracting novel insights into the interplay between these aspects of students' lives.

# %% [markdown]
# ### **Stakeholders**
# ####***Students 👨‍🎓 :***
#
# The primary stakeholders in this challenge are students
# themselves. Understanding how their social relationships, physical and mental health, and emotional resilience affect their academic success and overall development is crucial for their well-being and future success.
#
#
# ---
#
#
# ####***Educators 👨‍🏫 :***
#
# Educators, including teachers, counselors, and administrators, play a vital role in supporting students' academic and personal growth. They would benefit from a deeper understanding of the factors that influence student success so they can provide more effective support and interventions.
#
#
# ---
#
#
# ####***Parents and families 👪:***
#
# Parents and families play a critical role in
# their children's lives and want to support their academic and personal
# development. Understanding the intricate interactions within students' lives can help parents and families be more effective advocates and provide better support at home.

# %% [markdown]
# **Descriptive Statistics:**
#
# 1-How many individuals are included in the dataset?
#
# 2-What is the mean anxiety level reported by participants?
#
# 3-How many respondents have a documented history of mental health issues?
#
#
# **Psychological Factors:**
#
# 1-How many participants exhibit self-esteem levels below the mean?
#
# 2-What percentage of respondents report experiencing symptoms of depression?
#
# **Physiological Factors:**
#
# 1- How many individuals frequently experience headaches?
#
# 2- What is the average blood pressure reading recorded among participants?
#
# 3- How many respondents rate their sleep quality as poor?
#
#
# **Academic Factors:**
#
# 1-How many participants assess their academic performance as below average?
#
# 2-What is the mean study load reported by respondents?
#
# 3-How many individuals express concerns about their future career prospects?

# %% [markdown]
# # **Step 2: Data Understanding and  Exploration**

# %% [markdown]
# This dataset contains around 20 features that create the most impact on the Stress of a Student. The features are selected scientifically considering 5 major factors, they are Psychological, Physiological, Social, Environmental, and Academic Factors
#
#
# ### **Person-related features :**
#
# -**Psychological Factors** => anxiety_level,self_esteem,mental_health_history,depression
#
# -**Physiological Factors** => headache,blood_pressure,sleep_quality,breathing_problem
#
# -**Environmental Factors** => noise_level,living_conditions,safety,basic_needs
#
# -**Academic Factors** => academic_performance,study_load,teacher_student_relationship,future_career_concerns
#
# -**Social Factor** => social_support,peer_pressure,extracurricular_activities,bullying
#
#
# and other features : origin/english_name/arabic_name

# %% [markdown]
# * Import libraries

# %%
#data manipulation and analysis
import numpy as np
import pandas as pd
#creating various types of plots and visualizations
import matplotlib.pyplot as plt
import seaborn as sns
#Normalization
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Initial Data Exploration
# Here are the steps we've taken during the Data Understanding phase:
#
# * Loading the Dataset: We loaded the dataset from the "StressLevelDataset.csv"
# file to examine its contents.

# %%
data = pd.read_csv("globalDataset.csv")

# %%
# Displaying the first few rows of the 'data' DataFrame to inspect its initial data entries
pd.set_option('display.max_columns', None)
data.head(5)
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  safety  basic_needs  academic_performance  study_load  \
# ...

# %% [markdown]
# * Data Structure: We determined the size of the dataset (number of rows and columns) to understand its overall dimensions.

# %%
data.shape
# Out:
# (1100, 21)

# %% [markdown]
# => **The dataset contains a total of 1100 records and 21 features.**

# %%
#the list of column names in the DataFrame 'data'
data.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'stress_level'],
#       dtype='object')

# %%
data.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %% [markdown]
# => Summary Statistics: We calculated basic summary statistics, such as mean, standard deviation, and quartiles, for numerical features to get a sense of the data's distribution.

# %%
# Output a summary of information about the DataFrame 'data,' including data types, non-null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %% [markdown]
# => these Summary statistics provide a basic understanding of the distribution of numerical features.

# %% [markdown]
# # **Step 3: Data Preparation (cleaning)**

# %% [markdown]
# ### 1-**Dimensionality Reduction**

# %% [markdown]
# the Environmental Factors (living_conditions,safety,basic_needs) does not directly relate to the focus on mental and physical health, emotional resilience, and social relationships in the context of data analysis.
#
# **=> we have omitted those features**

# %%
columns_to_remove = ['noise_level', 'living_conditions', 'safety', 'basic_needs']
data = data.drop(columns=columns_to_remove)

# %% [markdown]
# ### 2- **Detect Outliers**

# %%
#we use the boxplot to detect any outliers
plt.figure(figsize=(12, 8))
sns.boxplot(data)
plt.title('Boxplot for Each Attribute')
plt.xticks(fontsize=8, rotation=45, ha="right")
plt.show()

# %% [markdown]
# => We identified outliers within the dataset, specifically in the **'study load'** feature  has 0 and 5 as extreme values

# %%
data['study_load'] = data['study_load'].replace({0: 2, 5: 2.62})

# %% [markdown]
# => Replace all occurrences of 0 and 5 in 'study_load' with the mean value (2.62)

# %% [markdown]
# ### 3-**Duplicate Records**

# %%
data.duplicated().sum()
# Out:
# 2

# %% [markdown]
# => on a 2 duplicated records

# %%
data = data.drop_duplicates()

# %% [markdown]
# => we removed duplicate rows from  DataFrame

# %% [markdown]
# ### 4-**missing values**

# %%
plt.figure(figsize=(15, 5))
sns.heatmap(data=data.isnull(),cbar=True, cmap="GnBu")
plt.title('Missing values heatmap')
plt.show()

# %% [markdown]
# => This visualization can serve as a confirmation that Our dataset does not contain any missing values.

# %% [markdown]
# In the context of our study, academic experiences are influenced by a combination of various factors, including social, psychological, and physiological elements. These factors collectively contribute to shaping the overall academic performance, study load, teacher-student relationships, and concerns about future career paths.
#
#
#
# **=> For these reasons ,  we decided to Understand the interconnectedness of each one of :  social, psychological, and physiological with academic performances**

# %%
# Define the relevant columns
psychological_factors = ['anxiety_level', 'self_esteem', 'mental_health_history', 'depression']
physiological_factors = ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem']
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']
social_factors = ['social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']

# Calculate the number of students with negative experiences or conditions for each factor
num_students_with_negative_psychological = data[psychological_factors].apply(lambda x: x.lt(3).sum(), axis=1)
num_students_with_negative_physiological = data[physiological_factors].apply(lambda x: x.gt(3).sum(), axis=1)
num_students_with_negative_academic = data[academic_factors].apply(lambda x: x.lt(3).sum(), axis=1)
num_students_with_negative_social = data[social_factors].apply(lambda x: x.gt(3).sum(), axis=1)

# Create a bar chart for the number of students with various negative experiences or conditions
factors = ['Psychological', 'Physiological', 'Academic', 'Social']
negative_experiences = [
    num_students_with_negative_psychological.sum(),
    num_students_with_negative_physiological.sum(),
    num_students_with_negative_academic.sum(),
    num_students_with_negative_social.sum()
]

plt.figure(figsize=(10, 6))
sns.barplot(x=factors, y=negative_experiences)
plt.title("Number of Students Reporting Negative Experiences or Conditions by Factor")
plt.xlabel("Factors")
plt.ylabel("Number of Students")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **=> most of students  consider the academic factors as  a negative experiences**

# %% [markdown]
# ##1- **physiological reasons in relation with academic experiences**

# %% [markdown]
# 1-first We will explore the distribution of each individual feature to gain
# insights into their respective patterns and variations.

# %%
physiological_factors = ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem']




    # Define the number of rows for subplots
num_rows = len(physiological_factors) // 3 + (len(physiological_factors) % 3 > 0)  # 3 columns per row

    # Create a figure and axes for each subplot
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 4 * num_rows))

    # Plot the distribution of each float column in a subplot
for i, column in enumerate(physiological_factors):
        row, col = i // 3, i % 3
        sns.histplot(data[column], kde=True, ax=axes[row, col], bins=20)
        axes[row, col].set_title(column)
        axes[row, col].set_xlabel('Values')
        axes[row, col].set_ylabel('Frequency')

    # Adjust the spacing between subplots
plt.tight_layout()

    # Show the figure
plt.show()

# %% [markdown]
# **=> After analyzing the distribution of physiological factors, it is evident that the most prevalent issues among the surveyed individuals are related to sleep quality and blood pressure.**

# %% [markdown]
# -**Correaltion between academic factors and physiological factors**

# %%
# Assume data is your DataFrame
physiological_factors = ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem']
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']

# Select the relevant columns
selected_columns = physiological_factors + academic_factors

# Create a new DataFrame with only the selected columns
selected_df = data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix between Physiological and Academic Factors')
plt.show()

# %% [markdown]
# **=> There is a notable correlation between "academic factors"  and "physiological factors", as evidenced by strong associations observed in specific pairs. For instance, we observe a significant correlation between "sleep quality" and "future career concerns", highlighting the potential impact of one's sleep quality on their long-term career apprehensions**

# %% [markdown]
# ##2- **Psychological reasons in relation with academic experiences**

# %% [markdown]
# 1-first We will explore the distribution of each individual feature to gain
# insights into their respective patterns and variations.

# %%
psychological_factors = ['anxiety_level', 'self_esteem', 'mental_health_history', 'depression']
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']

# Define the number of rows for subplots
num_rows = len(psychological_factors) // 3 + (len(psychological_factors) % 3 > 0)  # 3 columns per row

# Create a figure and axes for each subplot
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 4 * num_rows))

# Plot the distribution of each psychological factor using a violinplot
for i, column in enumerate(psychological_factors):
    row, col = i // 3, i % 3
    sns.violinplot(x=data[column], ax=axes[row, col], inner="quartile", palette="pastel")
    axes[row, col].set_title(column)
    axes[row, col].set_xlabel('Values')

# Adjust the spacing between subplots
plt.tight_layout()

# Show the figure
plt.show()

# %% [markdown]
# **=>In the analysis of psychological factors, a noteworthy observation is the presence of high values for depression and anxiety levels.**

# %% [markdown]
# -**Correaltion between academic factors and physiological factors**

# %%
# Assume data is your DataFrame
psychological_factors = ['anxiety_level', 'self_esteem', 'mental_health_history', 'depression']
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']

# Select the relevant columns
selected_columns = psychological_factors + academic_factors

# Create a new DataFrame with only the selected columns
selected_df = data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix between psychological_factors and Academic Factors')
plt.show()

# %% [markdown]
# **=> In our analysis, a strong correlation has been identified between psychological factors and academic experiences. Notably, the most significant correlations emerge in the association between depression and future career concerns, as well as anxiety and future career concerns. These particular correlations underscore a noteworthy relationship, suggesting that higher levels of depression and anxiety are linked to increased concerns about future career paths.**

# %% [markdown]
# ##3- **social reasons in relation with academic experiences**

# %% [markdown]
# 1-first We will explore the distribution of each individual feature to gain
# insights into their respective patterns and variations.

# %%
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']

social_factors = ['social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']



    # Define the number of rows for subplots
num_rows = len(social_factors) // 3 + (len(social_factors) % 3 > 0)  # 3 columns per row

    # Create a figure and axes for each subplot
fig, axes = plt.subplots(num_rows, 3, figsize=(15, 4 * num_rows))

    # Plot the distribution of each float column in a subplot
for i, column in enumerate(social_factors):
        row, col = i // 3, i % 3
        sns.histplot(data[column], kde=True, ax=axes[row, col], bins=20)
        axes[row, col].set_title(column)
        axes[row, col].set_xlabel('Values')
        axes[row, col].set_ylabel('Frequency')

    # Adjust the spacing between subplots
plt.tight_layout()

    # Show the figure
plt.show()

# %% [markdown]
# **=>Upon examining the distribution of social factors, particularly social support, peer pressure, extracurricular activities, and bullying, noteworthy patterns have emerged. The histogram analysis reveals a positive trend for 'social_support,' indicating a generally favorable distribution.**

# %% [markdown]
# -**Correaltion between academic factors and social factors**

# %%
# Assume data is your DataFrame
social_factors = ['social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']
academic_factors = ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns']

# Select the relevant columns
selected_columns = social_factors + academic_factors

# Create a new DataFrame with only the selected columns
selected_df = data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix between social_factors and Academic Factors')
plt.show()

# %% [markdown]
# **=>While it's true that nearly all features exhibit some level of correlation, a noteworthy observation stands out. Specifically, an evident direct impact has been identified, indicating that 'bullying' significantly influences 'future_career_concerns'**

# %% [markdown]
# ##**General Conclusion**

# %% [markdown]
# ###=> in analyzing the data, a clear trend emerges regarding the influence of different groups of factors on academic performance.
#
# ### **1-Psychological factors : appear to be the most predominant, exerting a significant influence on academic outcomes**
#
#  ### **2-Following closely in the hierarchy of influence are social factors, contributing their own impact to academic experiences.**
#
#  ### **3-Finally, while still present, the influence of physical factors seems to be slightly less pronounced in comparison** ###
#
# ### **This hierarchy suggests that mental health and psychological aspects play a central role, closely followed by social interactions, while physical factors also have their own influence, though slightly less pronounced, on overall academic performance.**

# %% [markdown]
# # **Step 4:  Modeling**

# %% [markdown]
# #**K-Means**

# %% [markdown]
# **K-means clustering is an appropriate method for analyzing the relationship between psychological, physiological, social, and academic factors in student stress for 2  reasons**
#
# #**1-Unsupervised Learning**:
# K-means is an unsupervised learning algorithm, In the context of student stress, we may not have clear-cut categories or labels for the different levels or types of academic experiences.
#
# #**2-Grouping and Pattern Recognition**:
# This can help identify patterns and relationships between the various factors that contribute to student stress. For instance, we might find that students with poor sleep quality tend to have higher levels of anxiety and academic stress.

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Standardisez les données si nécessaire
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Utilisez la méthode du coude pour trouver le nombre optimal de clusters
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(data_scaled)
    wcss.append(kmeans.inertia_)

# Tracez la méthode du coude pour visualiser le nombre optimal de clusters
plt.plot(range(1, 11), wcss)
plt.title('Méthode du coude')
plt.xlabel('Nombre de clusters')
plt.ylabel('WCSS')  # Within-Cluster Sum of Squares
plt.show()

# %% [markdown]
# **=> choosing the best parameter to know the best number   using the elbow method**

# %%
# Choisissez le nombre optimal de clusters en fonction de la méthode du coude
optimal_k = 2# Remplacez par le nombre optimal que vous avez identifié
# Ajoutez les étiquettes des clusters à votre DataFrame
data['cluster'] = kmeans.labels_
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', max_iter=300, n_init=10, random_state=42)
kmeans.fit(data_scaled)
# Out:
# KMeans(n_clusters=2, n_init=10, random_state=42)

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Assume data is your DataFrame


# Perform K-Means clustering
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=42)
kmeans.fit(data)
# Apply PCA to reduce dimensionality to 2 components


pca = PCA(n_components=2)  # Reduce to 2 components
pca_result = pca.fit_transform(data)

# Add the cluster labels to the PCA result
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])
pca_df['cluster'] = kmeans.labels_

# Plot the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PC1', y='PC2', hue='cluster', palette='viridis', data=pca_df)
plt.title('K-Means Clustering of  Academic Factors')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.show()

# %% [markdown]
# **=> Cluster 0, Cluster 1, and Cluster 2 represent three distinct groups of students. Each group is characterized by specific traits and behaviors, as indicated by the average values of the features.**

# %%
# Calculate cluster means for each attribute
cluster_means = data[data['cluster'].isin([0, 1, 2])].groupby('cluster').mean()

# Transpose the DataFrame for plotting
cluster_means = cluster_means.T

# Plot the cluster means as bar plots
cluster_means.plot(kind='bar', figsize=(12, 6), colormap='viridis')
plt.title('Moyennes des Caractéristiques par Cluster')
plt.xlabel('Caractéristique')
plt.ylabel('Valeur Moyenne')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# Based on the analysis using K-Means clustering, we have identified three distinct clusters among the individuals:
#
# ###**The first cluster** :
# consists of individuals with a high level of depression. This group exhibits characteristics associated with increased levels of depression, which may include feelings of sadness, hopelessness, and a negative outlook on life.
#
# ###**The second cluster** :
# comprises individuals with high self-esteem. This group displays attributes related to a positive self-perception, including confidence, self-worth, and a strong belief in their abilities and value.
#
# ###**The third cluster :**
#  represents individuals with moderate levels of depression and self-esteem. This group falls between the extremes of the first two clusters, displaying a more balanced combination of psychological factors.
